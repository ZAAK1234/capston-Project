# %%
import pandas as pd

# %%
df1=pd.read_csv('final_data.csv')
df1.drop('Unnamed: 0',inplace=True,axis=1)
df1
# Out:
#           STATE/UT  YEAR  Population  Male_pop  Female_pop  Literacy  \
# 0    A & N ISLANDS  2001      356152    192972      163180     81.30
# 1    A & N ISLANDS  2002      358523    193940      164578     81.81
# 2    A & N ISLANDS  2003      360909    194912      165988     82.33
# 3    A & N ISLANDS  2004      363312    195890      167410     82.84
# 4    A & N ISLANDS  2005      365730    196873      168844     83.36
# ..             ...   ...         ...       ...         ...       ...
# 415    WEST BENGAL  2008    87793758  45137586    42655472     73.97
# 416    WEST BENGAL  2009    88939526  45687994    43250991     74.73
# 417    WEST BENGAL  2010    90100247  46245114    43854825     75.50
# 418    WEST BENGAL  2011    91276116  46809028    44467088     76.26
# 419    WEST BENGAL  2012    92467331  47379817    45087900     77.02
#
#      Male Literacy  Female Literacy Area (km2)  MURDER  ...  \
# 0            86.30            75.24      8,249      13  ...
# ...
